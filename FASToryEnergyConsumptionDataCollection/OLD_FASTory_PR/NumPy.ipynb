# %% [markdown]
# In this part we do the following two tasks:
# 1. Firstly, we analysize the power comsumption data from Energy Modules.
# 2. Secondly, we label the data with load values which is based on power consumption values of CNVs and put the loads in same class which have 10 percent of power consumption varation from ground truth value
#
# ### Note:
# **Workstation 09** is used to collect power consumption data of CNVs, both main and bypass convetors are used and data is collected for variable loads. Here Load is the number of pallets that are being processed by CNV at a time.<br> There are approximately **3800** EM data values which are collected after every 1 second.

# %% [markdown]
# # Part 1: EM Data Anlysis and Data Labeling

# %%
# Importing modules
import pandas as pd
import numpy as np
from collections import Counter
# %matplotlib inline
import matplotlib.pyplot as plt
from mpl_toolkits import mplot3d

# %% [markdown]
# ## Multiple Outputs
# For seeing the multiple outputs from each cell, uncomment the following imports.

# %% [markdown]
# #### File Reading

# %%
df_L = pd.read_csv('_Tension_L10.csv')
df_N = pd.read_csv('_Tension_N10_.csv')
df_T = pd.read_csv('_Tension_T10.csv')
pd.set_option('display.max_columns', 10)
pd.set_option('display.max_rows', 100)
# print(df_L.shape,df_N.shape, df_T.shape)
samples=df_L.index[0:135:1] # customize number of samples (x_axis values)
# df.drop(samples,inplace=True)
# df.to_csv('_Tension_NB10.csv',index=False)


# #df_1000= df.iloc[samples]
powerL=df_L['Power(W)'][samples] # y_axis values .loc[:,['Power(W)']]
#styles=plt.style.available
powerN=df_N['Power(W)'][samples]#.loc[:,['Power(W)']]
powerT=df_T['Power(W)'][samples]#.loc[:,['Power(W)']]
plt.rcParams['figure.figsize'] = (8.0, 5.0)
# plt.rcParams.update({'font.size': 30})
plt.style.use('fivethirtyeight') #'seaborn-darkgrid',  'fivethirtyeight'
#plt.scatter(samples,power,s=15,marker='.')
#plt.plot(power, marker='o', linestyle='none', markersize=10,markerfacecolor='none')
plt.plot(powerL,linewidth=1.5,label='Belt_Loose',color='b')
plt.plot(powerN,linewidth=1.5,label='Belt_Normal',color='g' )
plt.plot(powerT,linewidth=1.5,color='r',label='Belt_Tighten' )
#plt.axis([0, 4000, 330, 430])
#plt.xticks(rotation=90)
SMALL_SIZE = 10
MEDIUM_SIZE = 15
BIGGER_SIZE = 20
CUSTOM_SIZE = 15
#plt.rc('font', size=MEDIUM_SIZE)          # controls default text sizes
plt.rc('axes', titlesize=MEDIUM_SIZE)     # fontsize of the axes title
plt.rc('axes', labelsize=CUSTOM_SIZE)    # fontsize of the x and y labels
plt.rc('xtick', labelsize=SMALL_SIZE)    # fontsize of the tick labels
plt.rc('ytick', labelsize=SMALL_SIZE)    # fontsize of the tick labels
plt.rc('legend', fontsize=SMALL_SIZE)    # legend fontsize
plt.rc('figure', titlesize=BIGGER_SIZE)  # fontsize of the figure title
plt.xticks(rotation=45)
plt.xticks(np.arange(0,150,10))
plt.yticks(np.arange(220, 300,10))
plt.xlabel('Number of Samples',color='#4390cb')
plt.ylabel('Power in Watts',color='#4390cb')
#plt.title('Power Consumed by WS 9 CNV according to successive increment of Load',color='#4390cb')
plt.legend(bbox_to_anchor=(1,1))
plt.show()

# %%
df = pd.read_csv('_Measurements10.csv')
pd.set_option('display.max_columns', 10)
pd.set_option('display.max_rows', 100)
print(df.shape)
# samples=df.index[450:500:1] # customize number of samples (x_axis values)
# df.drop(samples,inplace=True)
# df.to_csv('_Tension_NB10.csv',index=False)


# #df_1000= df.iloc[samples]
power=df.loc[:,['Power(W)']]#[samples] # y_axis values
# #styles=plt.style.available
plt.rcParams['figure.figsize'] = (8.0, 5.0)
# # plt.rcParams.update({'font.size': 30})
plt.style.use('fivethirtyeight') #'seaborn-darkgrid',  'fivethirtyeight'
#plt.scatter(samples,power,s=15,marker='.')
#plt.plot(power, marker='o', linestyle='none', markersize=10,markerfacecolor='none')
plt.plot(power,linewidth=2,color='#4390cb' )
#plt.axis([0, 4000, 330, 430])
plt.xticks(rotation=90)
SMALL_SIZE = 15
MEDIUM_SIZE = 15
BIGGER_SIZE = 20
CUSTOM_SIZE = 20
#plt.rc('font', size=MEDIUM_SIZE)          # controls default text sizes
plt.rc('axes', titlesize=MEDIUM_SIZE)     # fontsize of the axes title
plt.rc('axes', labelsize=CUSTOM_SIZE)    # fontsize of the x and y labels
plt.rc('xtick', labelsize=SMALL_SIZE)    # fontsize of the tick labels
plt.rc('ytick', labelsize=SMALL_SIZE)    # fontsize of the tick labels
plt.rc('legend', fontsize=SMALL_SIZE)    # legend fontsize
plt.rc('figure', titlesize=BIGGER_SIZE)  # fontsize of the figure title
plt.xticks(np.arange(0,1900,100))
plt.yticks(np.arange(460, 505,5))
plt.xlabel('Number of Samples',color='#4390cb')
plt.ylabel('Power in Watts',color='#4390cb')
plt.title('Power Consumed by WS 10 CNV according to successive increment of Load',color='#4390cb')
plt.show()

########################3D#####################################
# Out:
# (1806, 11)

# %%
# df = pd.read_csv('N_Measurements9.csv')
# pd.set_option('display.max_columns', 10)
# pd.set_option('display.max_rows', 100)
# print(df.shape)
# df.head()

# %%
# samples=df.index[0:None:1] # customize number of samples (x_axis values)
# power=df.loc[:,['Power(W)']]#[samples] # y_axis values
# #styles=plt.style.available
# plt.rcParams['figure.figsize'] = (16.0, 10.0)
# # plt.rcParams.update({'font.size': 30})
# #plt.style.use('fivethirtyeight') #'seaborn-darkgrid',  'fivethirtyeight'
# #plt.scatter(samples,power,s=15,marker='.')
# #plt.plot(power, marker='o', linestyle='none', markersize=10,markerfacecolor='none')
# plt.plot(power,linewidth=2,color='#4390cb' )
# #plt.axis([0, 4000, 330, 430])
# #plt.xticks(rotation=90)
# SMALL_SIZE = 15
# MEDIUM_SIZE = 15
# BIGGER_SIZE = 20
# CUSTOM_SIZE = 25
# #plt.rc('font', size=MEDIUM_SIZE)          # controls default text sizes
# plt.rc('axes', titlesize=MEDIUM_SIZE)     # fontsize of the axes title
# plt.rc('axes', labelsize=CUSTOM_SIZE)    # fontsize of the x and y labels
# plt.rc('xtick', labelsize=SMALL_SIZE)    # fontsize of the tick labels
# plt.rc('ytick', labelsize=SMALL_SIZE)    # fontsize of the tick labels
# plt.rc('legend', fontsize=SMALL_SIZE)    # legend fontsize
# plt.rc('figure', titlesize=BIGGER_SIZE)  # fontsize of the figure title
# plt.xticks(np.arange(0,200,20))
# plt.yticks(np.arange(490, 530,10))
# plt.xlabel('Number of Samples',color='#4390cb')
# plt.ylabel('Power in Watts',color='#4390cb')
# plt.title('Power Consumed by WS 9 CNV according to successive increment of Load',color='#4390cb')
# plt.show()

# %% [markdown]
# ## Data Visulaziation

# %%
# samples=df.index[0:None:1] # customize number of samples (x_axis values)
# power=df['Power(W)'][samples] # y_axis values
# #styles=plt.style.available
# plt.rcParams['figure.figsize'] = (16.0, 10.0)
# # plt.rcParams.update({'font.size': 30})
# #plt.style.use('fivethirtyeight') #'seaborn-darkgrid',  'fivethirtyeight'
# #plt.scatter(samples,power,s=15,marker='.')
# #plt.plot(power, marker='o', linestyle='none', markersize=10,markerfacecolor='none')
# plt.plot(power,linewidth=2,color='#4390cb' )
# #plt.axis([0, 4000, 330, 430])
# #plt.xticks(rotation=90)
# SMALL_SIZE = 15
# MEDIUM_SIZE = 15
# BIGGER_SIZE = 20
# CUSTOM_SIZE = 25
# #plt.rc('font', size=MEDIUM_SIZE)          # controls default text sizes
# plt.rc('axes', titlesize=MEDIUM_SIZE)     # fontsize of the axes title
# plt.rc('axes', labelsize=CUSTOM_SIZE)    # fontsize of the x and y labels
# plt.rc('xtick', labelsize=SMALL_SIZE)    # fontsize of the tick labels
# plt.rc('ytick', labelsize=SMALL_SIZE)    # fontsize of the tick labels
# plt.rc('legend', fontsize=SMALL_SIZE)    # legend fontsize
# plt.rc('figure', titlesize=BIGGER_SIZE)  # fontsize of the figure title
# plt.xticks(np.arange(0,4000,300))
# plt.yticks(np.arange(340, 410,10))
# plt.xlabel('Number of Samples',color='#4390cb')
# plt.ylabel('Power in Watts',color='#4390cb')
# plt.title('Power Consumed by WS 9 CNV according to successive increment of Load',color='#4390cb')
# plt.show()

# #sorted(Counter(df['Power(W)']).items())

# %% [markdown]
#  #### Saving the Data Frame to a Seprate File for Further Analysis
#  Here i also, make sub-dataframes for each load catagorey.

# %%
#df.to_csv('N_Measurements9_labled.csv',index=False)
#df = pd.read_csv('N_Measurements9_labled.csv')
filt0=(df['Label'] ==0)
filt1=(df['Label'] ==1)
filt2=(df['Label'] ==2)
filt3=(df['Label'] ==3)
filt4=(df['Label'] ==4)

# y=df.loc[fil,'label']
# print(dict(Counter(y)).items())
df0=df.loc[filt0,'Power(W)']
df1=df.loc[filt1,'Power(W)']
df2=df.loc[filt2,'Power(W)']
df3=df.loc[filt3,'Power(W)']
df4=df.loc[filt4,'Power(W)']
# # Counting the power values in each sub data-frame
# print(Counter(df0))
# print(Counter(df1))
# print(Counter(df2))
# print(Counter(df3))
# print(Counter(df4))
# df0.to_csv('measurements09_0.csv')
# df1.to_csv('measurements09_1.csv')
# df2.to_csv('measurements09_2.csv')
# df3.to_csv('measurements09_3.csv')
# df4.to_csv('measurements09_4.csv')

# %% [markdown]
# ### Visulaizing CNV Power Consumption for Successive increase in  Load

# %%
plt.style.use('fivethirtyeight')
df0=df.loc[filt0,'Power(W)'] 
x0=df0.index[0:None:1]
y0=df0[x0]
plt.plot(y0, marker='o', linestyle='none', markersize=10,label='0_Pallet',markerfacecolor='none')
# # #########################
df1=df.loc[filt1,'Power(W)'] 
x1=df1.index[0:None:1]
y1=df1[x1]
plt.plot(y1, marker='+', linestyle='none', markersize=10,label='1_Pallet',markerfacecolor='none')
###########################
df2=df.loc[filt2,'Power(W)'] 
x2=df2.index[0:None:1]
y2=df2[x2]
plt.plot(y2, marker='x', linestyle='none', markersize=10,label='2_Pallets',markerfacecolor='none')
###########################
df3=df.loc[filt3,'Power(W)'] 
x3=df3.index[0:None:1]
y3=df3[x3]
plt.plot(y3, marker='v', linestyle='none', markersize=10,markerfacecolor='none',label='3_Pallets',color='k')
##########################
df4=df.loc[filt4,'Power(W)'] 
x4=df4.index[0:None:1]
y4=df4[x4]
plt.plot(y4, marker='4', linestyle='none', markersize=10,label='4_Pallets',markerfacecolor='none',color='#5531E0')
##########################
#plt.rc('font', size=MEDIUM_SIZE)          # controls default text sizes
plt.rc('axes', titlesize=MEDIUM_SIZE)     # fontsize of the axes title
plt.rc('axes', labelsize=CUSTOM_SIZE)    # fontsize of the x and y labels
plt.rc('xtick', labelsize=SMALL_SIZE)    # fontsize of the tick labels
plt.rc('ytick', labelsize=SMALL_SIZE)    # fontsize of the tick labels
plt.rc('legend', fontsize=SMALL_SIZE)    # legend fontsize
plt.rc('figure', titlesize=BIGGER_SIZE)  # fontsize of the figure title
plt.xticks(np.arange(0,4000,300))
plt.yticks(np.arange(340, 410,10))
#plt.xticks(rotation=90)
# plt.xticks(np.arange(0,4000,200))
# plt.yticks(np.arange(330, 430,10))
plt.xlabel('Number of Samples',color='#4390cb')
plt.ylabel('Power Consumption in Watts',color='#4390cb')
plt.legend()
plt.title('Power Consumed by CNV according to Load',color='#4390cb')
plt.show()

# %% [markdown]
# ### Visulation of Binary Classification of Data
# The data is classified into two classes though we have five different load cases i.e. 0-4. The reason, for making this multiclass problem a binary is that energy values for different load cases flacutates too much and results in data overlapping. Furthermore we have trained and tested different ML model for the multiclass classification problem but the obtained results are not favourable.
# Though the above picture shows distinict thresholds on power consumed by CNV for different cases but this is obtained by data preprocessing and cleaning.<br>**Class 1** corresponds to 0 or 1 pallet on CNV at a time
# <br>**Class 2** corresponds to 2-3 or more then 3 pallets on CNV at a time

# %%
y1=df.loc[df['Class']==1,'Power(W)'] 

#plt.plot(y0,linewidth=1,label='0_Pallet')
plt.plot(y1, marker='o', linestyle='none', markersize=8,label='Class1:0 or 1 Pallets',markerfacecolor='none')

y2=df.loc[df['Class']==2,'Power(W)'] 
plt.plot(y2, marker='x', linestyle='none', markersize=10,label='Class2: 2-4_Pallets')
#plt.rc('font', size=MEDIUM_SIZE)          # controls default text sizes
plt.rc('axes', titlesize=MEDIUM_SIZE)     # fontsize of the axes title
plt.rc('axes', labelsize=CUSTOM_SIZE)    # fontsize of the x and y labels
plt.rc('xtick', labelsize=SMALL_SIZE)    # fontsize of the tick labels
plt.rc('ytick', labelsize=SMALL_SIZE)    # fontsize of the tick labels
plt.rc('legend', fontsize=MEDIUM_SIZE)    # legend fontsize
plt.rc('figure', titlesize=BIGGER_SIZE)  # fontsize of the figure title
#plt.axis([0, 4000, 330, 430])
#plt.xticks(rotation=90)
plt.xticks(np.arange(0,4000,300))
plt.yticks(np.arange(340, 410,10))
plt.xlabel('Number of Samples',color='#4390cb')
plt.ylabel('Power Consumption in Watts',color='#4390cb')
plt.title('Classification based on CNV Power Consumption',color='#4390cb')
plt.legend()

# %% [markdown]
# # Part 2: Traning ML model

# %%
from sklearn.model_selection import train_test_split
from sklearn import svm
from sklearn.metrics import accuracy_score
from sklearn.model_selection import validation_curve

# %% [markdown]
# ### Extracting random 1000 rows
# This data is used as external data for model testing

# %%
df = pd.read_csv('N_Measurements9.csv')
n = 1000  # for random indices
index = np.random.choice(df.shape[0], n, replace=False) 
df_1000= df.iloc[index]
df.drop(index,inplace=True)
df_1000.to_csv('crossValidation.csv',index=False)
df.to_csv('traningData.csv',index=False)

# %% [markdown]
# #### File reading and extracting necessary features columns and label columns

# %%
data = pd.read_csv('traningData.csv')
data.head()

#this gives series
# X = data['Active_Power(W)']
# y = data['lable']

# this gives dataframe
X = data[['Power(W)']]
# y = data[['label']]
y = data[['Class']]
X=np.array(X)
y=np.array(y)
print(X.shape,type(X))
print(y.shape,type(y))

# %% [markdown]
# #### Spliting data for traning and testing data sets

# %%
X_train, X_test, y_train, y_test= train_test_split(X,y, test_size= 0.3, random_state=109, shuffle= True)
print(X_train.shape)
print(y_train.shape)
print(X_test.shape)
print(y_test.shape)

# %% [markdown]
# #### Traning, Fitting and Prediction

# %%
C = [0.001, 0.01, 0.1, 1, 10, 100,1000]  # SVM regularization parameter
g = [0.0001, 0.001, 0.01, 1] 
# models = (svm.SVC(kernel='linear', C=C),
#           svm.LinearSVC(C=C, max_iter=10000),
#           svm.SVC(kernel='rbf', gamma=g, C=C),
#           svm.SVC(kernel='poly', degree=3, gamma='auto', C=C))
# models = [clf.fit(X_train, y_train) for clf in models]
# names=['SVC_Kl', 'LSVC', 'rbf', 'poly3']
# i=0
# for model in models:
#     predictions= model.predict(X_test)
#     print(f'Accuracy of "{names[i]}" is {accuracy_score(y_test,predictions)}')
#     i=i+1

# %%
model= svm.SVC(kernel='rbf', gamma=g[1], C=C[0])
model.fit(X_train, y_train)
predictions= model.predict(X_test)
accuracy_score(y_test,predictions)

# %% [markdown]
# # Random Experiments

# %%
external_data= pd.read_csv('crossValidation.csv')
print('CrossValidationData: ',external_data.shape)
X_ext = external_data[['Power(W)']]
=np.array(X_ext)
y_ext = external_data[['Class']]
y_ext=np.array(y_ext)
print('X_ext: ',X_ext.shape)
print('y_ext: ',y_ext.shape)

# %%
clf=['SVC_Kl', 'LSVC', 'rbf', 'poly3']
j=0
scores={}
for model in models:
    predictions= model.predict(X_ext)
    print(f'Accuracy of "{clf[j]}" is {accuracy_score(y_ext,predictions)}')
    scores[clf[j]]= predictions
    j=j+1

# %%
scores

# %%
c_ext_1=external_data.loc[external_data['Class']==1] 
x_ext_1=c_ext_1.index[0:None:1]
y_ext_1=(c_ext_1['Power(W)'][x_ext_1]) 

c_ext_2=external_data.loc[external_data['Class']==2] 
x_ext_2=c_ext_2.index[0:None:1]
y_ext_2=(c_ext_2['Power(W)'][x_ext_2]) 

pc1=predictions==1
c1_pred=predictions[pc1]
pc2=predictions==2
c2_pred=predictions[pc2]

plt.subplot(2, 1, 1)
plt.plot(x_ext_1,y_ext_1 ,marker='o', linestyle='none', markersize=5,label='Class1')
plt.plot(x_ext_2,y_ext_2 ,marker='*', linestyle='none', markersize=5,label='Class2')
plt.subplot(2, 1, 2)

plt.plot(x_ext_1,c1_pred ,marker='o', linestyle='none', markersize=5,label='Class1')
plt.plot(x_ext_2,c2_pred,marker='*', linestyle='none', markersize=5,label='Class2')
# plt.legend()
plt.show()

# %%
pc1=predictions==1
c1_pred=predictions[pc1]
pc2=predictions==2
c2_pred=predictions[pc2]

# %%
predictions=np.array(predictions)

# %%
print(predictions.shape,y_ext.shape)

# %%
np.allclose(predictions,y_ext.transpose()[0])

# %%
df_L = pd.read_csv('s_measurements10.csv')
# df_N = pd.read_csv('_Tension_N10_.csv')
# df_T = pd.read_csv('_Tension_T10.csv')
pd.set_option('display.max_columns', 10)
pd.set_option('display.max_rows', 100)
# print(df_L.shape,df_N.shape, df_T.shape)
#samples=df_L.index[0:135:1] # customize number of samples (x_axis values)
# df.drop(samples,inplace=True)
# df.to_csv('_Tension_NB10.csv',index=False)


# #df_1000= df.iloc[samples]
beltT20=df_L['%Belt Tension']==20 # y_axis values .loc[:,['Power(W)']]
beltT40=df_L['%Belt Tension']==40
beltT60=df_L['%Belt Tension']==60
#styles=plt.style.available
# powerN=df_N['Power(W)'][samples]#.loc[:,['Power(W)']]
# powerT=df_T['Power(W)'][samples]#.loc[:,['Power(W)']]
# plt.rcParams['figure.figsize'] = (8.0, 5.0)
# # plt.rcParams.update({'font.size': 30})
# plt.style.use('fivethirtyeight') #'seaborn-darkgrid',  'fivethirtyeight'
# #plt.scatter(samples,power,s=15,marker='.')
# #plt.plot(power, marker='o', linestyle='none', markersize=10,markerfacecolor='none')
# plt.plot(powerL,linewidth=1.5,label='Belt_Loose',color='b')
# plt.plot(powerN,linewidth=1.5,label='Belt_Normal',color='g' )
# plt.plot(powerT,linewidth=1.5,color='r',label='Belt_Tighten' )
# #plt.axis([0, 4000, 330, 430])
# #plt.xticks(rotation=90)
# SMALL_SIZE = 10
# MEDIUM_SIZE = 15
# BIGGER_SIZE = 20
# CUSTOM_SIZE = 15
# #plt.rc('font', size=MEDIUM_SIZE)          # controls default text sizes
# plt.rc('axes', titlesize=MEDIUM_SIZE)     # fontsize of the axes title
# plt.rc('axes', labelsize=CUSTOM_SIZE)    # fontsize of the x and y labels
# plt.rc('xtick', labelsize=SMALL_SIZE)    # fontsize of the tick labels
# plt.rc('ytick', labelsize=SMALL_SIZE)    # fontsize of the tick labels
# plt.rc('legend', fontsize=SMALL_SIZE)    # legend fontsize
# plt.rc('figure', titlesize=BIGGER_SIZE)  # fontsize of the figure title
# plt.xticks(rotation=45)
# plt.xticks(np.arange(0,150,10))
# plt.yticks(np.arange(220, 300,10))
# plt.xlabel('Number of Samples',color='#4390cb')
# plt.ylabel('Power in Watts',color='#4390cb')
# #plt.title('Power Consumed by WS 9 CNV according to successive increment of Load',color='#4390cb')
# plt.legend(bbox_to_anchor=(1,1))
# plt.show()

# %%
# df_L.loc[df_L['%Belt Tension']==20]
t=df_L['Power (W)'][beltT20]
plt.plot(t, marker='o', linestyle='none', markersize=10,markerfacecolor='none')
plt.yticks(np.arange(225, 233,1))
plt.show()

# %%
# df0=df_L.loc[(df_L['%Belt Tension']==60) & (df_L['Load Alias']==0),['Power (W)']]
# df1=df_L.loc[(df_L['%Belt Tension']==60) & (df_L['Load Alias']==1),['Power (W)']]
# df2=df_L.loc[(df_L['%Belt Tension']==60) & (df_L['Load Alias']==2),['Power (W)']]
# df3=df_L.loc[(df_L['%Belt Tension']==60) & (df_L['Load Alias']==3),['Power (W)']]
# df4=df_L.loc[(df_L['%Belt Tension']==60) & (df_L['Load Alias']==4),['Power (W)']]
# df5=df_L.loc[(df_L['%Belt Tension']==60) & (df_L['Load Alias']==5),['Power (W)']]
# df6=df_L.loc[(df_L['%Belt Tension']==60) & (df_L['Load Alias']==6),['Power (W)']]
# df7=df_L.loc[(df_L['%Belt Tension']==60) & (df_L['Load Alias']==7),['Power (W)']]
# df8=df_L.loc[(df_L['%Belt Tension']==60) & (df_L['Load Alias']==8),['Power (W)']]
# df9=df_L.loc[(df_L['%Belt Tension']==60) & (df_L['Load Alias']==9),['Power (W)']]
# df10=df_L.loc[(df_L['%Belt Tension']==60) & (df_L['Load Alias']==10),['Power (W)']]
# df11=df_L.loc[(df_L['%Belt Tension']==60) & (df_L['Load Alias']==11),['Power (W)']]
# df12=df_L.loc[(df_L['%Belt Tension']==60) & (df_L['Load Alias']==12),['Power (W)']]
# df13=df_L.loc[(df_L['%Belt Tension']==60) & (df_L['Load Alias']==13),['Power (W)']]
# df14=df_L.loc[(df_L['%Belt Tension']==60) & (df_L['Load Alias']==14),['Power (W)']]
# df15=df_L.loc[(df_L['%Belt Tension']==60) & (df_L['Load Alias']==15),['Power (W)']]

df00=pd.read_csv('BT60_0.csv')
df11=pd.read_csv('BT60_1.csv')
df22=pd.read_csv('BT60_2.csv')
df33=pd.read_csv('BT60_3.csv')
df44=pd.read_csv('BT60_4.csv')
df55=pd.read_csv('BT60_5.csv')
df66=pd.read_csv('BT60_6.csv')
df77=pd.read_csv('BT60_7.csv')
df88=pd.read_csv('BT60_8.csv')
df99=pd.read_csv('BT60_9.csv')
df100=pd.read_csv('BT60_10.csv')
df111=pd.read_csv('BT60_11.csv')
df122=pd.read_csv('BT60_12.csv')
df133=pd.read_csv('BT60_13.csv')
df144=pd.read_csv('BT60_14.csv')
df155=pd.read_csv('BT60_15.csv')

# %%
plt.rcParams['figure.figsize'] = (10.0, 8.0)
# plt.rcParams.update({'font.size': 30})
plt.style.use('fivethirtyeight') #'seaborn-darkgrid',  'fivethirtyeight'

# %%
# #One pallet at different zones
# plt.plot(df11, marker='o', linestyle='none', markersize=5,label='Z1=1')#,markerfacecolor='none'
# plt.plot(df22, marker='o', linestyle='none', markersize=5,label='Z2=1')
# plt.plot(df44, marker='o', linestyle='none', markersize=5,label='Z3=1')
# plt.plot(df88, marker='o', linestyle='none', markersize=5,label='Z5=1')
# # plt.yticks(np.arange(238, 250,2))
# # plt.xticks(np.arange(60,150,10))
# plt.legend()
# plt.show()
data=[df00['Power (W)'],df11['Power (W)'],df22['Power (W)'],df44['Power (W)'],df88['Power (W)']]
fig = plt.figure(figsize =(10, 7))
ax = fig.add_axes([0, 0, 1, 1])
bp = ax.boxplot(data)
ax.set_xticklabels(['Comb_0', 'Comb_1', 
                    'Comb_2', 'Comb_4','Comb_8'])
plt.yticks(np.arange(238, 248,1))
plt.show()

# %%
#Two pallets at different zones 1
# plt.plot(df33, marker='o', linestyle='none', markersize=5,label='Z1 and Z2')#, marker='o', linestyle='none', markersize=5
# plt.plot(df55, marker='o', linestyle='none', markersize=5,label='Z1 and Z3')
# plt.plot(df66, marker='o', linestyle='none', markersize=5,label='Z2 and Z2')
# #plt.plot(df99)
# plt.plot(df100)
# plt.plot(df122)
# plt.legend()
# plt.show()
data=[df33['Power (W)'],df55['Power (W)'],df66['Power (W)'],df99['Power (W)'],
      df100['Power (W)'],df122['Power (W)']]
fig = plt.figure(figsize =(10, 7))
ax = fig.add_axes([0, 0, 1, 1])
bp = ax.boxplot(data)
ax.set_xticklabels(['Comb_3', 'Comb_5', 
                    'Comb_6', 'Comb_9','Comb_10','Comb_12'])
plt.yticks(np.arange(242, 253,1))
plt.show()

# %%
#Two pallets at different zones 2
# plt.plot(df99, marker='o', linestyle='none', markersize=5,label='Z1 and Z5')
# plt.plot(df100, marker='o', linestyle='none', markersize=5,label='Z2 and Z5')
# plt.plot(df122, marker='o', linestyle='none', markersize=5,label='Z3 and Z5')
# plt.legend()
# plt.show()

# %%
#Three pallets at different zones 
# plt.plot(df77, marker='o', linestyle='none', markersize=5,label='Z1,Z2 and Z3')
# plt.plot(df111, marker='o', linestyle='none', markersize=5,label='Z1,Z2 and Z5')
# plt.plot(df133, marker='o', linestyle='none', markersize=5,label='Z1,Z3 and Z5')
# plt.plot(df144, marker='o', linestyle='none', markersize=5,label='Z3,Z2 and Z5')
# plt.legend()
# plt.show()
data=[df77['Power (W)'],df111['Power (W)'],df133['Power (W)'],df144['Power (W)']]
fig = plt.figure(figsize =(10, 7))
ax = fig.add_axes([0, 0, 1, 1])
bp = ax.boxplot(data)
ax.set_xticklabels(['Comb_7', 'Comb_11', 
                    'Comb_13', 'Comb_14'])
plt.yticks(np.arange(241, 256,1))
plt.show()

# %%
#One pallet at each Zone
# plt.plot(df155, marker='o', linestyle='none')
# plt.show()
data=[df00['Power (W)'],df11['Power (W)'],df22['Power (W)'],df44['Power (W)'],
      df88['Power (W)'],df33['Power (W)'],df55['Power (W)'],df66['Power (W)'],
      df99['Power (W)'],df100['Power (W)'],df122['Power (W)'],df77['Power (W)'],
      df111['Power (W)'],df133['Power (W)'],df144['Power (W)'],df155['Power (W)']]
fig = plt.figure(figsize =(10, 7))
ax = fig.add_axes([0, 0, 1, 1])
bp = ax.boxplot(data)
ax.set_xticklabels(['Comb_0', 'Comb_1', 
                    'Comb_2', 'Comb_4','Comb_8','Comb_3', 'Comb_5', 
                    'Comb_6', 'Comb_9','Comb_10','Comb_12','Comb_7', 'Comb_11', 
                    'Comb_13', 'Comb_14','Comb_15'])
plt.yticks(np.arange(238, 256,1))
plt.show()
