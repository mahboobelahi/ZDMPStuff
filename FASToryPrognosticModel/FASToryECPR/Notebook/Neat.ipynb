# %%
# Importing modules
import pandas as pd
import numpy as np
from collections import Counter
# %matplotlib inline
import matplotlib.pyplot as plt
import sqlite3
import seaborn as sns
from pprint import pprint
#######################
import tensorflow as tf
#tf.keras.model
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import LabelBinarizer
from sklearn.model_selection import train_test_split
import pandas
from keras.models import Sequential, save_model, load_model
from keras.layers import Dense
from keras.wrappers.scikit_learn import KerasClassifier
from keras.utils import np_utils
from sklearn.model_selection import cross_val_score
from sklearn.metrics import accuracy_score
from sklearn.model_selection import KFold
from sklearn.preprocessing import LabelEncoder
from sklearn.pipeline import Pipeline
from keras.utils import to_categorical
import matplotlib.pyplot as plt
from keras.regularizers import l2
# %matplotlib inline

# %% [markdown]
# # Data Preprocessing
# 1. Data Normalization
#     1. "Normalized Power" contains normalized values using default sklearn parameters
#     2. "NNormalied Power" contains normalized values using custom normalization range [0-320].
#     3. Load Normalization
#     4. Belt Tension Normalization

# %%
df= pd.read_csv("s_Measurements10.csv")

# %%
df.describe()
# Out:
#        RMS Current (A)  RMS Voltage (V)  Load Combinations  %Belt Tension  \
# count      4559.000000      4559.000000        4559.000000    4559.000000
# mean          2.244258       239.086049           6.597938      79.479052
# std           0.133051         1.576013           4.953935      18.555136
# min           0.536000       236.398000           0.000000       0.000000
# 25%           2.160000       237.286500           2.000000      75.000000
# 50%           2.178000       239.969000           6.000000      85.000000
# 75%           2.372000       240.456000          11.000000      95.000000
# max           2.618000       241.591000          15.000000      95.000000
#
#          Power (W)  %Power/Nominal_Power  Normalized_Power  \
# count  4559.000000           4559.000000       4559.000000
# mean    249.911384             25.464795          0.395264
# std      15.004988              1.507339          0.220939
# min     223.000000             23.000000          0.000000
# 25%     240.000000             24.000000          0.250000
# 50%     244.000000             25.000000          0.310000
# 75%     266.000000             27.000000          0.630000
# max     291.000000             30.000000          1.000000
#
#        Normalized_Belt_Tension  Normalized_Load      Class_3      Class_4  \
# count              4559.000000      4559.000000  4559.000000  4559.000000
# mean                  0.835517         0.439925     2.159903     2.740952
# std                   0.194638         0.330031     0.623588     1.010374
# min                   0.000000         0.000000     1.000000     1.000000
# 25%                   0.790000         0.130000     2.000000     2.000000
# 50%                   0.890000         0.400000     2.000000     3.000000
# 75%                   1.000000         0.730000     3.000000     4.000000
# max                   1.000000         1.000000     3.000000     4.000000
#
#            Class_9  NNNormalized_Power         Load        Load1
# count  4559.000000         4559.000000  4559.000000  4559.000000
# mean      7.472911            0.299114     1.772318     1.604738
# std       1.690149            0.150050     1.128014     0.488961
# min       1.000000            0.030000     0.000000     1.000000
# 25%       7.000000            0.200000     1.000000     1.000000
# 50%       8.000000            0.240000     2.000000     2.000000
# 75%       9.000000            0.460000     3.000000     2.000000
# max       9.000000            0.710000     4.000000     2.000000

# %% [markdown]
# # Data Normalization

# %%
# #Saving Scalar for real-time usage
# import joblib

# scaler_filename =[ "Power-scaler.save","pallet-scaler.save","custom-Power-scaler.save"]
# data_frame = [ df[['Power (W)']],df[['Load Alias']],df[['Power (W)']] ]
# for data,name in zip(data_frame,scaler_filename): 

#     if name=="custom-Power-scaler.save":
#         scaler = MinMaxScaler()
#         x_sample = [220, 320]
#         scaler.fit(np.array(x_sample)[:, np.newaxis])
#         #scaler.fit(data)
#         joblib.dump(scaler, name) 
#         print('If: ',scaler.data_max_,scaler.data_min_)
#     else:
#         scaler = MinMaxScaler()
#         scaler.fit(data)
#         joblib.dump(scaler, name) 
#         #scaler = joblib.load(name)
#         print(scaler.data_max_,scaler.data_min_)


# scaler = MinMaxScaler()
# df['Normalized_Power']=scaler.fit_transform(df[['Power (W)']])
# df['Normalized_Belt_Tension']=scaler.fit_transform(df[['%Belt Tension']])
# df['Normalized_Load']=scaler.fit_transform(df[['Load Alias']])

# df['Normalized_Power']=round(df['Normalized_Power'],2)
# df['Normalized_Belt_Tension']=round(df['Normalized_Belt_Tension'],2)
# df['Normalized_Load']=round(df['Normalized_Load'],2)

## Coustomize Power(W)  and Belt Tension scaling.
# scaler = MinMaxScaler()
# x_sample = [220, 320]
# scaler.fit(np.array(x_sample)[:, np.newaxis])
# #df['NNNormalized_Power']= scaler.fit_transform(df[['Power (W)']])
# df['NNNormalized_Power']=scaler.transform(df[['Power (W)']])
# df['NNNormalized_Power']=round(df['NNNormalized_Power'],2)


#df['NNormalized_Power']= round((df[['Power (W)']]-df[['Power (W)']].min())/(320-df[['Power (W)']].min()),2)
#df.to_csv('s_Measurements10.csv',index=False)


#print(np.allclose(df['NNNormalized_Power'], df['NNormalized_Power']))
#print(scaler.data_max_,scaler.data_min_)

# %%
# from sklearn.preprocessing import QuantileTransformer
# qt = QuantileTransformer(n_quantiles=1000, random_state=0)

# df['Qt-Normalized_Power1']=qt.fit_transform(df[['Power (W)']])
# df['Qt-Normalized_Power1']=round(df['Qt-Normalized_Power1'],4)

# df['Qt-Normalized_Load']=qt.fit_transform(df[['Load Alias']])
# df['Qt-Normalized_Load']=round(df['Qt-Normalized_Load'],4)

#df.to_csv('s_Measurements10.csv',index=False)
# b=scaler.transform(np.array([226], ndmin=2))
# a
# b
# print(a.ndim,b.ndim,np.append(a,b))

# %%
df_min= df['Normalized_Power']
df_cus= df['NNNormalized_Power']
df_qt= df['Qt-Normalized_Power']
df_qt1= df['Qt-Normalized_Power1']

# %%
plt.figure(figsize =(10.0,7.0))
plt.style.use('fivethirtyeight')
#plt.plot(df_min,label='min')
# plt.plot(df_qt,label='qt')
# plt.plot(df_cus,label='cus')
#plt.plot(df_qt1,label='qt1')
plt.plot(df_cus, marker='o', linestyle='none', markersize=5,label='qt1',markerfacecolor='none',color='k')
plt.plot(df_qt, marker='+', linestyle='none', markersize=5,label='min',markerfacecolor='none',color='r')
plt.xticks(np.arange(0,5000,500))
plt.yticks(np.arange(0, 1.05,0.05))
plt.legend()

# %%
# qt = QuantileTransformer(n_quantiles=1000, random_state=0)

# df['Qt-log']=qt.fit_transform(np.log(df[['Power (W)']]))
# df['Qt-log']=round(df['Qt-log'],4)
# from sklearn.preprocessing import RobustScaler
# transformer = RobustScaler().fit(df[['Power (W)']])
# df['robust']=transformer.transform(df[['Power (W)']])
# df['robust']=round(df['robust'],4)
# df.to_csv('s_Measurements10.csv',index=False)
# pd.read_csv('s_Measurements10.csv')
# df_min= df['Normalized_Power']
# df_cus= df['NNNormalized_Power']
# df_qt= df['Qt-Normalized_Power']
# df_qt1= df['Qt-Normalized_Power1']
# df_qtlog=df['Qt-log']
df_robust=df['robust']
plt.plot(df_robust, marker='o', linestyle='none', markersize=5,label='robust',markerfacecolor='none',color='k')
plt.plot(df_qt, marker='+', linestyle='none', markersize=5,label='qt',markerfacecolor='none',color='r')
plt.legend()

# %% [markdown]
# # Data Class Labeling based on Belt Tension
#
# This data is collected for conveyor belt tension ranging from 0% to 95%, there are 9 different belt tensions values in this range. In the data there are three different belt tension class label columns:
# ### 1. Class_3:
# 1. All Not Usefull Belt tensions are combined in a Class
# 2. Moderate and Useful(Optimal), belt tensions are combined in a sperate class
# 3. Over Tense belt Tension has a huge power consumption margin among other belt tensions so it has its own class
# Please see the following table:
# ## Class_3
#
# | Belt Tension Class | %Belt Tension | Description|
# |:--------------------|:-------------|:------------|
# |1 | 0 | Not Useful
# |1 | 15 | Not Useful
# |1 | 30 | Not Useful
# |1 | 45 | Not Useful
# |1 | 60 | Not Useful
# |1 | 70 | Not Useful
# |2 | 75 | Moderate Useful
# |2 | 85 | Useful (Optimal)
# |3 | 95 | Over Tense
#
# ### 2. Class_4:
# 1. All Not Usefull Belt tensions are combined in a class
# 2. Moderate and Useful(Optimal), belt tensions have  sperate classes
# 3. Over Tense belt Tension has a huge power consumption margin among other belt tensions so it has its own class
# Please see the following table:
#
# ## Class_4
#
# | Belt Tension Class | %Belt Tension | Description|
# |:--------------------|:-------------|:------------|
# |1 | 0 | Not Useful
# |1 | 15 | Not Useful
# |1 | 30 | Not Useful
# |1 | 45 | Not Useful
# |1 | 60 | Not Useful
# |1 | 70 | Not Useful
# |2 | 75 | Moderate Useful
# |3 | 85 | Useful (Optimal)
# |4 | 95 | Over Tense
#
# ### 3. Class_9
# 1. Default, Each belt tension has its own class
#
# Please see the following table:
# ## Class_9
#
# | Belt Tension Class | %Belt Tension | Description|
# |:--------------------|:-------------|:------------|
# |1 | 0 | Not Useful
# |2 | 15 | Not Useful
# |3 | 30 | Not Useful
# |4 | 45 | Not Useful
# |5 | 60 | Not Useful
# |6 | 70 | Not Useful
# |7 | 75 | Moderate Useful
# |8 | 85 | Useful (Optimal)
# |9 | 95 | Over Tense
#
# The belt tension predictor's accuracy significantly effected by the belt tension class labeling. Please the follwing picture.
#
# In the picture each box plot shoes the power consumption of conveyory belt with all zone combinations for a specific belt tension.
# #### Observations:
#
# 1. The belt tension range: 0%-60% are not useful for us as with these belt tensions the ius no motion in the conveyor belt and data mean is approximately same (0-30 and 45-60) for these combinations.
# 2. The belt tension 70% is also not useful though this belt tension creates motion in the the belt but as soon as ther is a pallet on zone1 the jerky motion starts.
# 3. For there belt tensions the data is collected only for 0 (for 0%-70%) and 1 (only for 70%) load combinations.
# 4. The belt tension predictor mostly mispredict the belt tension class in that range so by grouping them in one class
# has huge affect on predictor accuracy also ant tension value which is less than or equal to 70% is not useful for our production system.
# 5. Similarly, for belt tensions 75% and 85% the margin between the belt power consumption for different load combinations is very small and for some load combinations the power consumption values overlaps with each other, though the belt tension is different. These belt tensions are grouped under one class, please see class_3 tabel. More detailed analysis of these belt tension can be found in **Main CNV Static Data Analysis** file.

# %% [markdown]
# ## Labeling Belt tension into Class

# %%
# choices=[1,2,3,4,5,6,7,8,9] #[1,1,1,1,1,1,1,2,3,4],[1,1,1,1,1,1,1,2,2,3]
# conditions= [
#             df['%Belt Tension'].eq(0),df['%Belt Tension'].eq(15),df['%Belt Tension'].eq(30),
#             df['%Belt Tension'].eq(45),df['%Belt Tension'].eq(60),df['%Belt Tension'].eq(70),
#             df['%Belt Tension'].eq(75),df['%Belt Tension'].eq(85),df['%Belt Tension'].eq(95)
#             ]
# df['Class9'] = np.select(conditions, choices, default= df['%Belt Tension'])

# df.to_csv('s_Measurements10.csv',index=False)
# df= pd.read_csv("s_Measurements10.csv")

# %%
choices=[0,1,1,1,1,
         2,2,2,2,2,2,
         3,3,3,3,
        4] #[1,1,1,1,1,1,1,2,3,4],[1,1,1,1,1,1,1,2,2,3]
conditions= [
            df['Load Alias'].eq(0),
            df['Load Alias'].eq(1),df['Load Alias'].eq(2),df['Load Alias'].eq(4),df['Load Alias'].eq(8),

            df['Load Alias'].eq(3),df['Load Alias'].eq(5),df['Load Alias'].eq(6),df['Load Alias'].eq(9),
            df['Load Alias'].eq(10),df['Load Alias'].eq(12),

            df['Load Alias'].eq(7),df['Load Alias'].eq(11),
            df['Load Alias'].eq(13),df['Load Alias'].eq(14),
    
            df['Load Alias'].eq(15)
            ]
df['load'] = np.select(conditions, choices, default= df['Load Alias'])

df.to_csv('s_Measurements10.csv',index=False)
df= pd.read_csv("s_Measurements10.csv")

# %% [markdown]
# ## One Hot Encoding (Learning Block)

# %%
class_encoder = LabelBinarizer()
class_encoder.fit(df['Class_3'])
transformed = class_encoder.transform(df['Class_3'])
oneHot_df = pd.DataFrame(transformed)
#df= pd.concat([df, oneHot_df], axis=1).drop(['Class'], axis=1)
#class_labels = np.argmax(class_prob, axis=1)

# %% [markdown]
# # Splitting Data for Traning, Cross Validation and Testing

# %%
# Randomly selecting "n" records for testing
def select_random(df,num):
      # for random indices
    index = np.random.choice(df.shape[0], num, replace=False) 
    df_500= df.iloc[index]
    #df.drop(index,inplace=True)
    df_500.to_csv('testData_349.csv',index=False)
    df.to_csv('traningData_349.csv',index=False)
    
# function Call
# df= pd.read_csv("s_Measurements10.csv")
# select_random(df,500)

# %% [markdown]
# # NN Model

# %% [markdown]
# # Helper Functions

# %% [markdown]
# ### Plot Loss and Accuracy

# %%
def plot_accuracy(history_dict,i):
    
    plt.style.use('fivethirtyeight')
    plt.rcParams['figure.figsize'] = (10.0, 7.0)
    
    acc_values = history_dict['accuracy']
    val_acc_values = history_dict['val_accuracy']

    epochs = range(1, len(acc_values) + 1)

    plt.plot(epochs, acc_values, 'bo', label="Training Accuracy")
    plt.plot(epochs, val_acc_values, 'r', label="Validation Accuracy")

    plt.title(f'Training and Validation Accuraccy_{i}')
    plt.yticks(np.arange(0,1.2,0.1))
    plt.xlabel('Epochs')
    plt.ylabel('Accuracy')
    plt.legend()
    plt.savefig(f'T_V_Validation_{i}.png',bbox_inches='tight')

    plt.show()
    
    
def plot_loss(history_dict,i):
    
    plt.style.use('fivethirtyeight')
    plt.rcParams['figure.figsize'] = (10.0, 7.0)
    
    loss_values = history_dict['loss']
    val_loss_values = history_dict['val_loss']

    epochs = range(1, len(loss_values) + 1)
    plt.rcParams['figure.figsize'] = (10.0, 7.0)
    plt.plot(epochs, loss_values, 'ro', label="Training Loss")
    plt.plot(epochs, val_loss_values, 'b', label="Validation Loss")
    plt.yticks(np.arange(0,1.2,0.1))
    plt.title(f'Training and Validation Loss_{i}')
    plt.xlabel('Epochs')
    plt.ylabel('Loss Value')
    plt.legend()
    plt.savefig(f'T_V_Loss_{i}.png',bbox_inches='tight')

    plt.show()

# %% [markdown]
# ### Train/Test split

# %%
def train_test(df,features,T_class=9):
    
    if T_class == 9:
        one_hot_encode = to_categorical(df['Class_9'])

    elif T_class ==4:
        one_hot_encode = to_categorical(df['Class_4'])
        print('HERERRR\n',one_hot_encode)
    
    elif T_class ==3:
        one_hot_encode = to_categorical(df['Class_3'])
        print('HERERRR\n',one_hot_encode)

    else:
        print(f'Wrong class value.....\nAllowed Classes are {3,4,9}!')
        
        return {"TT_split":f'Wrong class value.....\nAllowed Classes are {3,4,9}!'}

    X=np.array(df[features])
    #type(X)
    X_train, X_test, y_train, y_test = train_test_split(X,one_hot_encode, test_size=0.33, random_state=42)

    X_train= np.array(X_train)
    X_test= np.array(X_test)

    print(f'{type(X_train)} ,{X_train.shape}, {type(X_train)} , {X_test.shape}')
    print(f'{type(y_train)} ,{y_train.shape}, {type(y_train)},{y_test.shape}')

    return {"TT_split":( X_train, X_test, y_train, y_test)}

# %% [markdown]
# ### Model development and compilation

# %%
def NN_model(model_architecture=[10,10,10,10]):
    
    #build model
    model = Sequential()
    model.add(Dense(model_architecture[0], input_dim=2, activation='relu',kernel_regularizer=l2(0.01)))
    model.add(Dense(model_architecture[1], activation='relu',kernel_regularizer=l2(0.01)))
    model.add(Dense(model_architecture[2], activation='relu',kernel_regularizer=l2(0.01)))
    model.add(Dense(model_architecture[3], activation='softmax'))
    # Compile model
    model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
    
    return model

# %% [markdown]
# ### Fit Model

# %%
def fit_model(model,split,i,epocs=100):
    
    X_train, X_test, y_train, y_test= split.get("TT_split")
    # fit model
    history = model.fit(X_train,
                   y_train,
                   epochs=epocs,
                   batch_size=10,
                   validation_data=(X_test, y_test))
    
    model.save(f'M_iter3_{i}.h5') #using h5 extension
    return history

# %% [markdown]
# ### Belt Tension Evaluation and Prediction for unseen test data (500 samples)

# %%
def prdict_Tension_class(model,i,features,T_class=9):
    
    df_test= pd.read_csv('testData_349.csv')
    nn=np.random.randint(500, size=100)

    X_Test= np.array(df_test[features])
    
    if T_class == 9:

        y_Test=np.array(to_categorical(df_test[f'Class_{T_class}']))
        results = model.evaluate(X_Test, y_Test)
        
        #class prediction
        pred = model.predict(X_Test[nn]) 
        pred = np.argmax(pred, axis = 1)
        True_label = np.argmax(y_Test[nn],axis = 1)
        accuracy_score( True_label,pred )
        load = df_test['Load Alias'][nn] #(X_Test[nn][:,1]*16).astype(int)
        
        power = df_test['Power (W)'][nn]
        tem_df=df_test.loc[nn,['Load Alias','Power (W)','%Belt Tension',f'Class_{T_class}']]
        tem_df['Pred_BT_Class'] = pred

        tem_df.to_csv(f'pred{T_class}_{i}.csv',index=False)

        return (T_class,results[0],results[1],pred,True_label,load,power)
        
    elif T_class == 4:
        
        y_Test=np.array(to_categorical(df_test[f'Class_{T_class}']))
        results = model.evaluate(X_Test, y_Test)
        
        #class prediction
        pred = model.predict(X_Test[nn]) 
        pred = np.argmax(pred, axis = 1)
        True_label = np.argmax(y_Test[nn],axis = 1)
        accuracy_score( True_label,pred )
        
        load = df_test['Load Alias'][nn]
        power = df_test['Power (W)'][nn]
        
        tem_df=df_test.loc[nn,['Load Alias','Power (W)','%Belt Tension',f'Class_{T_class}']]
        tem_df['Pred_BT_Class'] = pred

        tem_df.to_csv(f'pred{T_class}_{i}.csv',index=False)
        
        return (T_class,results[0],results[1],pred,True_label,load,power)
        
    elif T_class == 3:
        
        y_Test=np.array(to_categorical(df_test[f'Class_{T_class}']))
        results = model.evaluate(X_Test, y_Test)
        
        #class prediction
        pred = model.predict(X_Test[nn]) 
        pred = np.argmax(pred, axis = 1)
        True_label = np.argmax(y_Test[nn],axis = 1)
        accuracy_score( True_label,pred )
        
        load = df_test['Load Alias'][nn]
        power = df_test['Power (W)'][nn]
        
        tem_df=df_test.loc[nn,['Load Alias','Power (W)','%Belt Tension',f'Class_{T_class}']]
        tem_df['Pred_BT_Class'] = pred

        tem_df.to_csv(f'pred{T_class}_{i}.csv',index=False)
        
        return (T_class,results[0],results[1],pred,True_label,load,power)
    
    else:

        return f'Wrong class value.....Allowed Classes are {3,4,9}!'

# %% [markdown]
# ## Main Block: All Functions are called in this block

# %%
# holds test data evaluation and predicted belt tension class 
cashe ={} # printing Average Loss and Accuracy

# reading trainiing data file
df_train= pd.read_csv("traningData_349.csv")
T_class = 3
epocs = 150
features= ['NNNormalized_Power','Normalized_Load']

# list contains number of hidden and output layer nodes
model_architecture = [10,10,6,4]
#if isinstance(split.get("TT_split"),tuple):
    
# build and compile model
model = NN_model(model_architecture)
    
"""
    For loop for getting average loss and accuracy
"""
for i in range(10):

    # spliting the data into train-test data 
    print(f'Splitting data {i+1}.\n')

    split = train_test(df_train,features,T_class)
    #X_train, X_test, y_train, y_test= split.get("TT_split")
    if isinstance(split.get("TT_split"),tuple):
        # fit model
        history = fit_model(model,split,i+1,epocs)

        # getting loss and accuracy for training and validation data
        history_dict = history.history
        print(history_dict.keys())

        # Plotting losses 
        plot_loss(history_dict,i+1)

        # Training and Validation Accuracy
        plot_accuracy(history_dict,i+1)

        res = prdict_Tension_class(model,i+1,features,T_class)


        if f'class_{T_class}' not in cashe:

            cashe[f'class_{T_class}'] = dict(
                            [('loss',[res[1]]), ('accuracy',[res[2]]),
                            ('true_classes',[res[3]]),('pred_classes', [res[4]]),
                             ('load',[res[5]]),('power',[res[6]])]
                             )
        else:
            temp = cashe.get(f'class_{T_class}')
            temp['loss'].append(res[1])
            temp['accuracy'].append(res[2])
            temp['true_classes'].append(res[3])
            temp['pred_classes'].append(res[4])
            temp['load'].append(res[5])
            temp['power'].append(res[6])
            #(T_class,results[0],results[1],True_label,pred,load,power)
    
    else:
        print(split.get("TT_split"))
        #print(prdict_Tension_class(1))
        
print(cashe.get(f'class_{T_class}'))
# Out:
# Splitting data 1.
#
# Wrong class value.....
# Allowed Classes are (3, 4, 9)!
# <class 'numpy.ndarray'> ,(3054, 1), <class 'numpy.ndarray'> , (1505, 1)
# <class 'numpy.ndarray'> ,(3054, 5), <class 'numpy.ndarray'>,(1505, 5)
# Epoch 1/150
# 306/306 [==============================] - 1s 3ms/step - loss: 1.7381 - accuracy: 0.2724 - val_loss: 1.5756 - val_accuracy: 0.3355
# Epoch 2/150
# 306/306 [==============================] - 1s 2ms/step - loss: 1.5577 - accuracy: 0.3287 - val_loss: 1.5079 - val_accuracy: 0.3355
# Epoch 3/150
# 306/306 [==============================] - 0s 1ms/step - loss: 1.5011 - accuracy: 0.3249 - val_loss: 1.4964 - val_accuracy: 0.3355
# Epoch 4/150
# 306/306 [==============================] - 1s 2ms/step - loss: 1.5005 - accuracy: 0.3229 - val_loss: 1.4947 - val_accuracy: 0.3355
# Epoch 5/150
# 306/306 [==============================] - 1s 2ms/step - loss: 1.4897 - accuracy: 0.3303 - val_loss: 1.4943 - val_accuracy: 0.3355
# Epoch 6/150
# 306/306 [==============================] - 0s 2ms/step - loss: 1.4888 - accuracy: 0.3331 - val_loss: 1.4937 - val_accuracy: 0.3355
# Epoch 7/150
# 306/306 [==============================] - 0s 1ms/step - loss: 1.5044 - accuracy: 0.3202 - val_loss: 1.4931 - val_accuracy: 0.3355
# Epoch 8/150
# 306/306 [==============================] - 1s 2ms/step - loss: 1.4929 - accuracy: 0.3185 - val_loss: 1.4928 - val_accuracy: 0.3355
# Epoch 9/150
# 306/306 [==============================] - 1s 2ms/step - loss: 1.5047 - accuracy: 0.3183 - val_loss: 1.4924 - val_accuracy: 0.3355
# Epoch 10/150
# 306/306 [==============================] - 1s 2ms/step - loss: 1.4996 - accuracy: 0.3240 - val_loss: 1.4923 - val_accuracy: 0.3355
# Epoch 11/150
# 306/306 [==============================] - 1s 2ms/step - loss: 1.4885 - accuracy: 0.3318 - val_loss: 1.4927 - val_accuracy: 0.3355
# Epoch 12/150
# 306/306 [==============================] - 1s 2ms/step - loss: 1.5047 - accuracy: 0.3303 - val_loss: 1.4923 - val_accuracy: 0.3355
# Epoch 13/150
# 306/306 [==============================] - 1s 2ms/step - loss: 1.4942 - accuracy: 0.3269 - val_loss: 1.4922 - val_accuracy: 0.3355
# Epoch 14/150
# 306/306 [==============================] - 1s 2ms/step - loss: 1.4868 - accuracy: 0.3318 - val_loss: 1.4923 - val_accuracy: 0.3355
# Epoch 15/150
# 306/306 [==============================] - 1s 2ms/step - loss: 1.4919 - accuracy: 0.3302 - val_loss: 1.4922 - val_accuracy: 0.3355
# Epoch 16/150
# 306/306 [==============================] - 0s 2ms/step - loss: 1.5076 - accuracy: 0.3169 - val_loss: 1.4919 - val_accuracy: 0.3355
# Epoch 17/150
# 306/306 [==============================] - 0s 1ms/step - loss: 1.4922 - accuracy: 0.3329 - val_loss: 1.4917 - val_accuracy: 0.3355
# Epoch 18/150
# 306/306 [==============================] - 0s 1ms/step - loss: 1.5033 - accuracy: 0.3228 - val_loss: 1.4922 - val_accuracy: 0.3355
# Epoch 19/150
# 306/306 [==============================] - 1s 2ms/step - loss: 1.5059 - accuracy: 0.3177 - val_loss: 1.4915 - val_accuracy: 0.3355
# Epoch 20/150
# 306/306 [==============================] - 0s 2ms/step - loss: 1.5075 - accuracy: 0.3126 - val_loss: 1.4916 - val_accuracy: 0.3355
# Epoch 21/150
# 306/306 [==============================] - 0s 2ms/step - loss: 1.4941 - accuracy: 0.3326 - val_loss: 1.4921 - val_accuracy: 0.3355
# Epoch 22/150
# 306/306 [==============================] - 0s 1ms/step - loss: 1.5061 - accuracy: 0.3103 - val_loss: 1.4918 - val_accuracy: 0.3355
# Epoch 23/150
# 306/306 [==============================] - 1s 2ms/step - loss: 1.4953 - accuracy: 0.3250 - val_loss: 1.4920 - val_accuracy: 0.3355
# Epoch 24/150
# 306/306 [==============================] - 0s 1ms/step - loss: 1.4809 - accuracy: 0.3411 - val_loss: 1.4924 - val_accuracy: 0.3355
# Epoch 25/150
# 306/306 [==============================] - 0s 1ms/step - loss: 1.4914 - accuracy: 0.3311 - val_loss: 1.4918 - val_accuracy: 0.3355
# Epoch 26/150
# 306/306 [==============================] - 1s 2ms/step - loss: 1.4934 - accuracy: 0.3311 - val_loss: 1.4916 - val_accuracy: 0.3355
# Epoch 27/150
# 306/306 [==============================] - 1s 2ms/step - loss: 1.4836 - accuracy: 0.3330 - val_loss: 1.4917 - val_accuracy: 0.3355
# Epoch 28/150
# 306/306 [==============================] - 1s 2ms/step - loss: 1.5001 - accuracy: 0.3235 - val_loss: 1.4915 - val_accuracy: 0.3355
# Epoch 29/150
# 306/306 [==============================] - 0s 2ms/step - loss: 1.5065 - accuracy: 0.3168 - val_loss: 1.4915 - val_accuracy: 0.3355
# Epoch 30/150
# 306/306 [==============================] - 1s 2ms/step - loss: 1.4937 - accuracy: 0.3343 - val_loss: 1.4921 - val_accuracy: 0.3355
# Epoch 31/150
# 306/306 [==============================] - 1s 2ms/step - loss: 1.4981 - accuracy: 0.3359 - val_loss: 1.4921 - val_accuracy: 0.3355
# Epoch 32/150
# 306/306 [==============================] - 0s 1ms/step - loss: 1.4991 - accuracy: 0.3124 - val_loss: 1.4917 - val_accuracy: 0.3355
# Epoch 33/150
# 306/306 [==============================] - 0s 1ms/step - loss: 1.5031 - accuracy: 0.3292 - val_loss: 1.4918 - val_accuracy: 0.3355
# Epoch 34/150
# 306/306 [==============================] - 1s 2ms/step - loss: 1.4944 - accuracy: 0.3225 - val_loss: 1.4920 - val_accuracy: 0.3355
# Epoch 35/150
# 306/306 [==============================] - 0s 1ms/step - loss: 1.4861 - accuracy: 0.3328 - val_loss: 1.4920 - val_accuracy: 0.3355
# Epoch 36/150
# 306/306 [==============================] - 1s 2ms/step - loss: 1.4931 - accuracy: 0.3276 - val_loss: 1.4919 - val_accuracy: 0.3355
# Epoch 37/150
# 306/306 [==============================] - 0s 2ms/step - loss: 1.4862 - accuracy: 0.3367 - val_loss: 1.4918 - val_accuracy: 0.3355
# Epoch 38/150
# 306/306 [==============================] - 1s 2ms/step - loss: 1.4996 - accuracy: 0.3188 - val_loss: 1.4919 - val_accuracy: 0.3355
# Epoch 39/150
# 306/306 [==============================] - 0s 1ms/step - loss: 1.4953 - accuracy: 0.3340 - val_loss: 1.4918 - val_accuracy: 0.3355
# Epoch 40/150
# 306/306 [==============================] - 1s 2ms/step - loss: 1.5135 - accuracy: 0.3136 - val_loss: 1.4915 - val_accuracy: 0.3355
# Epoch 41/150
# 306/306 [==============================] - 1s 2ms/step - loss: 1.4869 - accuracy: 0.3351 - val_loss: 1.4922 - val_accuracy: 0.3355
# Epoch 42/150
# 306/306 [==============================] - 1s 2ms/step - loss: 1.4842 - accuracy: 0.3466 - val_loss: 1.4923 - val_accuracy: 0.3355
# Epoch 43/150
# 306/306 [==============================] - 0s 2ms/step - loss: 1.4954 - accuracy: 0.3291 - val_loss: 1.4922 - val_accuracy: 0.3355
# Epoch 44/150
# 306/306 [==============================] - 1s 2ms/step - loss: 1.4890 - accuracy: 0.3335 - val_loss: 1.4918 - val_accuracy: 0.3355
# Epoch 45/150
# 306/306 [==============================] - 1s 2ms/step - loss: 1.5053 - accuracy: 0.3171 - val_loss: 1.4915 - val_accuracy: 0.3355
# Epoch 46/150
# 306/306 [==============================] - 0s 1ms/step - loss: 1.4933 - accuracy: 0.3137 - val_loss: 1.4914 - val_accuracy: 0.3355
# Epoch 47/150
# 306/306 [==============================] - 0s 1ms/step - loss: 1.5008 - accuracy: 0.3205 - val_loss: 1.4919 - val_accuracy: 0.3355
# Epoch 48/150
# 306/306 [==============================] - 0s 2ms/step - loss: 1.4922 - accuracy: 0.3295 - val_loss: 1.4920 - val_accuracy: 0.3355
# Epoch 49/150
# 306/306 [==============================] - 1s 2ms/step - loss: 1.4832 - accuracy: 0.3320 - val_loss: 1.4918 - val_accuracy: 0.3355
# Epoch 50/150
# 306/306 [==============================] - 0s 2ms/step - loss: 1.4900 - accuracy: 0.3309 - val_loss: 1.4921 - val_accuracy: 0.3355
# Epoch 51/150
# 306/306 [==============================] - 0s 2ms/step - loss: 1.5085 - accuracy: 0.3111 - val_loss: 1.4915 - val_accuracy: 0.3355
# Epoch 52/150
# 306/306 [==============================] - 1s 2ms/step - loss: 1.4971 - accuracy: 0.3145 - val_loss: 1.4915 - val_accuracy: 0.3355
# Epoch 53/150
# 306/306 [==============================] - 0s 1ms/step - loss: 1.4901 - accuracy: 0.3243 - val_loss: 1.4917 - val_accuracy: 0.3355
# Epoch 54/150
# 306/306 [==============================] - 1s 2ms/step - loss: 1.5090 - accuracy: 0.3138 - val_loss: 1.4916 - val_accuracy: 0.3355
# Epoch 55/150
# 306/306 [==============================] - 1s 2ms/step - loss: 1.4885 - accuracy: 0.3301 - val_loss: 1.4915 - val_accuracy: 0.3355
# Epoch 56/150
# 306/306 [==============================] - 1s 2ms/step - loss: 1.4977 - accuracy: 0.3273 - val_loss: 1.4918 - val_accuracy: 0.3355
# Epoch 57/150
# 306/306 [==============================] - 1s 2ms/step - loss: 1.5119 - accuracy: 0.3093 - val_loss: 1.4916 - val_accuracy: 0.3355
# Epoch 58/150
# 306/306 [==============================] - 0s 1ms/step - loss: 1.4934 - accuracy: 0.3299 - val_loss: 1.4916 - val_accuracy: 0.3355
# Epoch 59/150
# 306/306 [==============================] - 1s 2ms/step - loss: 1.5080 - accuracy: 0.3163 - val_loss: 1.4918 - val_accuracy: 0.3355
# Epoch 60/150
# 306/306 [==============================] - 0s 1ms/step - loss: 1.4936 - accuracy: 0.3280 - val_loss: 1.4919 - val_accuracy: 0.3355
# Epoch 61/150
# 306/306 [==============================] - 0s 2ms/step - loss: 1.5151 - accuracy: 0.3025 - val_loss: 1.4917 - val_accuracy: 0.3355
# Epoch 62/150
# 306/306 [==============================] - 0s 1ms/step - loss: 1.4861 - accuracy: 0.3377 - val_loss: 1.4917 - val_accuracy: 0.3355
# Epoch 63/150
# 306/306 [==============================] - 0s 2ms/step - loss: 1.5032 - accuracy: 0.3237 - val_loss: 1.4917 - val_accuracy: 0.3355
# Epoch 64/150
# 306/306 [==============================] - 0s 1ms/step - loss: 1.4798 - accuracy: 0.3360 - val_loss: 1.4919 - val_accuracy: 0.3355
# Epoch 65/150
# 306/306 [==============================] - 0s 1ms/step - loss: 1.4913 - accuracy: 0.3207 - val_loss: 1.4914 - val_accuracy: 0.3355
# Epoch 66/150
# 306/306 [==============================] - 0s 2ms/step - loss: 1.4890 - accuracy: 0.3303 - val_loss: 1.4915 - val_accuracy: 0.3355
# Epoch 67/150
# 306/306 [==============================] - 1s 2ms/step - loss: 1.4886 - accuracy: 0.3306 - val_loss: 1.4915 - val_accuracy: 0.3355
# Epoch 68/150
# 306/306 [==============================] - 1s 2ms/step - loss: 1.4987 - accuracy: 0.3384 - val_loss: 1.4920 - val_accuracy: 0.3355
# Epoch 69/150
# 306/306 [==============================] - 1s 2ms/step - loss: 1.4916 - accuracy: 0.3216 - val_loss: 1.4920 - val_accuracy: 0.3355
# Epoch 70/150
# 306/306 [==============================] - 1s 2ms/step - loss: 1.4909 - accuracy: 0.3322 - val_loss: 1.4918 - val_accuracy: 0.3355
# Epoch 71/150
# 306/306 [==============================] - 0s 2ms/step - loss: 1.4855 - accuracy: 0.3468 - val_loss: 1.4923 - val_accuracy: 0.3355
# Epoch 72/150
# 306/306 [==============================] - 0s 1ms/step - loss: 1.4942 - accuracy: 0.3222 - val_loss: 1.4916 - val_accuracy: 0.3355
# Epoch 73/150
# 306/306 [==============================] - 0s 1ms/step - loss: 1.4954 - accuracy: 0.3212 - val_loss: 1.4916 - val_accuracy: 0.3355
# Epoch 74/150
# 306/306 [==============================] - 1s 2ms/step - loss: 1.4936 - accuracy: 0.3193 - val_loss: 1.4914 - val_accuracy: 0.3355
# Epoch 75/150
# 306/306 [==============================] - 0s 1ms/step - loss: 1.4903 - accuracy: 0.3308 - val_loss: 1.4913 - val_accuracy: 0.3355
# Epoch 76/150
# 306/306 [==============================] - 1s 2ms/step - loss: 1.4940 - accuracy: 0.3246 - val_loss: 1.4917 - val_accuracy: 0.3355
# Epoch 77/150
# 306/306 [==============================] - 1s 2ms/step - loss: 1.4960 - accuracy: 0.3273 - val_loss: 1.4918 - val_accuracy: 0.3355
# Epoch 78/150
# 306/306 [==============================] - 0s 2ms/step - loss: 1.4936 - accuracy: 0.3241 - val_loss: 1.4917 - val_accuracy: 0.3355
# Epoch 79/150
# 306/306 [==============================] - 0s 1ms/step - loss: 1.4894 - accuracy: 0.3257 - val_loss: 1.4917 - val_accuracy: 0.3355
# Epoch 80/150
# 306/306 [==============================] - 0s 1ms/step - loss: 1.4878 - accuracy: 0.3376 - val_loss: 1.4919 - val_accuracy: 0.3355
# Epoch 81/150
# 306/306 [==============================] - 0s 1ms/step - loss: 1.4927 - accuracy: 0.3302 - val_loss: 1.4919 - val_accuracy: 0.3355
# Epoch 82/150
# 306/306 [==============================] - 0s 1ms/step - loss: 1.4997 - accuracy: 0.3238 - val_loss: 1.4917 - val_accuracy: 0.3355
# Epoch 83/150
# 306/306 [==============================] - 0s 1ms/step - loss: 1.4979 - accuracy: 0.3212 - val_loss: 1.4918 - val_accuracy: 0.3355
# Epoch 84/150
# 306/306 [==============================] - 0s 2ms/step - loss: 1.5034 - accuracy: 0.3187 - val_loss: 1.4916 - val_accuracy: 0.3355
# Epoch 85/150
# 306/306 [==============================] - 1s 2ms/step - loss: 1.4809 - accuracy: 0.3259 - val_loss: 1.4917 - val_accuracy: 0.3355
# Epoch 86/150
# 306/306 [==============================] - 1s 2ms/step - loss: 1.4909 - accuracy: 0.3210 - val_loss: 1.4915 - val_accuracy: 0.3355
# Epoch 87/150
# 306/306 [==============================] - 0s 1ms/step - loss: 1.4908 - accuracy: 0.3281 - val_loss: 1.4916 - val_accuracy: 0.3355
# Epoch 88/150
# 306/306 [==============================] - 1s 2ms/step - loss: 1.4770 - accuracy: 0.3451 - val_loss: 1.4920 - val_accuracy: 0.3355
# Epoch 89/150
# 306/306 [==============================] - 0s 2ms/step - loss: 1.4963 - accuracy: 0.3191 - val_loss: 1.4918 - val_accuracy: 0.3355
# Epoch 90/150
# 306/306 [==============================] - 0s 1ms/step - loss: 1.4901 - accuracy: 0.3430 - val_loss: 1.4918 - val_accuracy: 0.3355
# Epoch 91/150
# 306/306 [==============================] - 0s 2ms/step - loss: 1.4940 - accuracy: 0.3197 - val_loss: 1.4917 - val_accuracy: 0.3355
# Epoch 92/150
# 306/306 [==============================] - 1s 2ms/step - loss: 1.4782 - accuracy: 0.3299 - val_loss: 1.4915 - val_accuracy: 0.3355
# Epoch 93/150
# 306/306 [==============================] - 0s 2ms/step - loss: 1.4986 - accuracy: 0.3320 - val_loss: 1.4917 - val_accuracy: 0.3355
# Epoch 94/150
# 306/306 [==============================] - 0s 1ms/step - loss: 1.4992 - accuracy: 0.3247 - val_loss: 1.4915 - val_accuracy: 0.3355
# Epoch 95/150
# 306/306 [==============================] - 0s 2ms/step - loss: 1.5028 - accuracy: 0.3163 - val_loss: 1.4914 - val_accuracy: 0.3355
# Epoch 96/150
# 306/306 [==============================] - 1s 2ms/step - loss: 1.4887 - accuracy: 0.3416 - val_loss: 1.4919 - val_accuracy: 0.3355
# Epoch 97/150
# 306/306 [==============================] - 1s 2ms/step - loss: 1.4952 - accuracy: 0.3197 - val_loss: 1.4914 - val_accuracy: 0.3355
# Epoch 98/150
# 306/306 [==============================] - 1s 2ms/step - loss: 1.4868 - accuracy: 0.3257 - val_loss: 1.4916 - val_accuracy: 0.3355
# Epoch 99/150
# 306/306 [==============================] - 1s 2ms/step - loss: 1.4838 - accuracy: 0.3247 - val_loss: 1.4917 - val_accuracy: 0.3355
# Epoch 100/150
# 306/306 [==============================] - 0s 2ms/step - loss: 1.4894 - accuracy: 0.3293 - val_loss: 1.4918 - val_accuracy: 0.3355
# Epoch 101/150
# 306/306 [==============================] - 0s 1ms/step - loss: 1.4922 - accuracy: 0.3284 - val_loss: 1.4919 - val_accuracy: 0.3355
# Epoch 102/150
# 306/306 [==============================] - 0s 2ms/step - loss: 1.4999 - accuracy: 0.3181 - val_loss: 1.4916 - val_accuracy: 0.3355
# Epoch 103/150
# 306/306 [==============================] - 1s 2ms/step - loss: 1.4838 - accuracy: 0.3384 - val_loss: 1.4917 - val_accuracy: 0.3355
# Epoch 104/150
# 306/306 [==============================] - 0s 1ms/step - loss: 1.5047 - accuracy: 0.3170 - val_loss: 1.4915 - val_accuracy: 0.3355
# Epoch 105/150
# 306/306 [==============================] - 0s 1ms/step - loss: 1.4917 - accuracy: 0.3251 - val_loss: 1.4915 - val_accuracy: 0.3355
# Epoch 106/150
# 306/306 [==============================] - 1s 2ms/step - loss: 1.5001 - accuracy: 0.3218 - val_loss: 1.4917 - val_accuracy: 0.3355
# Epoch 107/150
# 306/306 [==============================] - 1s 2ms/step - loss: 1.4941 - accuracy: 0.3309 - val_loss: 1.4918 - val_accuracy: 0.3355
# Epoch 108/150
# 306/306 [==============================] - 0s 1ms/step - loss: 1.4817 - accuracy: 0.3308 - val_loss: 1.4920 - val_accuracy: 0.3355
# Epoch 109/150
# 306/306 [==============================] - 0s 1ms/step - loss: 1.4879 - accuracy: 0.3324 - val_loss: 1.4920 - val_accuracy: 0.3355
# Epoch 110/150
# 306/306 [==============================] - 1s 2ms/step - loss: 1.4934 - accuracy: 0.3326 - val_loss: 1.4920 - val_accuracy: 0.3355
# Epoch 111/150
# 306/306 [==============================] - 0s 2ms/step - loss: 1.4904 - accuracy: 0.3233 - val_loss: 1.4915 - val_accuracy: 0.3355
# Epoch 112/150
# 306/306 [==============================] - 1s 2ms/step - loss: 1.4923 - accuracy: 0.3259 - val_loss: 1.4919 - val_accuracy: 0.3355
# Epoch 113/150
# 306/306 [==============================] - 1s 2ms/step - loss: 1.4842 - accuracy: 0.3408 - val_loss: 1.4922 - val_accuracy: 0.3355
# Epoch 114/150
# 306/306 [==============================] - 1s 2ms/step - loss: 1.5022 - accuracy: 0.3204 - val_loss: 1.4917 - val_accuracy: 0.3355
# Epoch 115/150
# 306/306 [==============================] - 1s 2ms/step - loss: 1.4987 - accuracy: 0.3257 - val_loss: 1.4920 - val_accuracy: 0.3355
# Epoch 116/150
# 306/306 [==============================] - 1s 2ms/step - loss: 1.5016 - accuracy: 0.3193 - val_loss: 1.4918 - val_accuracy: 0.3355
# Epoch 117/150
# 306/306 [==============================] - 1s 2ms/step - loss: 1.5016 - accuracy: 0.3201 - val_loss: 1.4917 - val_accuracy: 0.3355
# Epoch 118/150
# 306/306 [==============================] - 0s 1ms/step - loss: 1.5004 - accuracy: 0.3189 - val_loss: 1.4916 - val_accuracy: 0.3355
# Epoch 119/150
# 306/306 [==============================] - 1s 2ms/step - loss: 1.4953 - accuracy: 0.3272 - val_loss: 1.4920 - val_accuracy: 0.3355
# Epoch 120/150
# 306/306 [==============================] - 1s 2ms/step - loss: 1.5106 - accuracy: 0.3230 - val_loss: 1.4921 - val_accuracy: 0.3355
# Epoch 121/150
# 306/306 [==============================] - 0s 1ms/step - loss: 1.4818 - accuracy: 0.3326 - val_loss: 1.4918 - val_accuracy: 0.3355
# Epoch 122/150
# 306/306 [==============================] - 0s 1ms/step - loss: 1.4940 - accuracy: 0.3229 - val_loss: 1.4916 - val_accuracy: 0.3355
# Epoch 123/150
# 306/306 [==============================] - 0s 2ms/step - loss: 1.4990 - accuracy: 0.3085 - val_loss: 1.4918 - val_accuracy: 0.3355
# Epoch 124/150
# 306/306 [==============================] - 1s 2ms/step - loss: 1.4931 - accuracy: 0.3289 - val_loss: 1.4918 - val_accuracy: 0.3355
# Epoch 125/150
# 306/306 [==============================] - 0s 2ms/step - loss: 1.4918 - accuracy: 0.3265 - val_loss: 1.4918 - val_accuracy: 0.3355
# Epoch 126/150
# 306/306 [==============================] - 1s 2ms/step - loss: 1.5000 - accuracy: 0.3197 - val_loss: 1.4917 - val_accuracy: 0.3355
# Epoch 127/150
# 306/306 [==============================] - 0s 2ms/step - loss: 1.5019 - accuracy: 0.3159 - val_loss: 1.4916 - val_accuracy: 0.3355
# Epoch 128/150
# 306/306 [==============================] - 0s 2ms/step - loss: 1.5018 - accuracy: 0.3153 - val_loss: 1.4916 - val_accuracy: 0.3355
# Epoch 129/150
# 306/306 [==============================] - 0s 2ms/step - loss: 1.4893 - accuracy: 0.3268 - val_loss: 1.4919 - val_accuracy: 0.3355
# Epoch 130/150
# 306/306 [==============================] - 0s 2ms/step - loss: 1.4957 - accuracy: 0.3175 - val_loss: 1.4918 - val_accuracy: 0.3355
# Epoch 131/150
# 306/306 [==============================] - 1s 2ms/step - loss: 1.4998 - accuracy: 0.3225 - val_loss: 1.4916 - val_accuracy: 0.3355
# Epoch 132/150
# 306/306 [==============================] - 0s 1ms/step - loss: 1.4942 - accuracy: 0.3287 - val_loss: 1.4917 - val_accuracy: 0.3355
# Epoch 133/150
# 306/306 [==============================] - 0s 1ms/step - loss: 1.5081 - accuracy: 0.3120 - val_loss: 1.4915 - val_accuracy: 0.3355
# Epoch 134/150
# 306/306 [==============================] - 0s 1ms/step - loss: 1.4834 - accuracy: 0.3268 - val_loss: 1.4916 - val_accuracy: 0.3355
# Epoch 135/150
# 306/306 [==============================] - 0s 1ms/step - loss: 1.5057 - accuracy: 0.3163 - val_loss: 1.4918 - val_accuracy: 0.3355
# Epoch 136/150
# 306/306 [==============================] - 0s 1ms/step - loss: 1.4886 - accuracy: 0.3274 - val_loss: 1.4918 - val_accuracy: 0.3355
# Epoch 137/150
# 306/306 [==============================] - 0s 1ms/step - loss: 1.4916 - accuracy: 0.3180 - val_loss: 1.4919 - val_accuracy: 0.3355
# Epoch 138/150
# 306/306 [==============================] - 1s 2ms/step - loss: 1.4972 - accuracy: 0.3369 - val_loss: 1.4923 - val_accuracy: 0.3355
# Epoch 139/150
# 306/306 [==============================] - 1s 2ms/step - loss: 1.5022 - accuracy: 0.3228 - val_loss: 1.4918 - val_accuracy: 0.3355
# Epoch 140/150
# 306/306 [==============================] - 0s 2ms/step - loss: 1.4865 - accuracy: 0.3328 - val_loss: 1.4917 - val_accuracy: 0.3355
# Epoch 141/150
# 306/306 [==============================] - 1s 2ms/step - loss: 1.4964 - accuracy: 0.3306 - val_loss: 1.4914 - val_accuracy: 0.3355
# Epoch 142/150
# 306/306 [==============================] - 1s 2ms/step - loss: 1.5060 - accuracy: 0.3222 - val_loss: 1.4914 - val_accuracy: 0.3355
# Epoch 143/150
# 306/306 [==============================] - 1s 2ms/step - loss: 1.4913 - accuracy: 0.3256 - val_loss: 1.4914 - val_accuracy: 0.3355
# Epoch 144/150
# 306/306 [==============================] - 1s 2ms/step - loss: 1.4997 - accuracy: 0.3201 - val_loss: 1.4917 - val_accuracy: 0.3355
# Epoch 145/150
# 306/306 [==============================] - 1s 2ms/step - loss: 1.4949 - accuracy: 0.3198 - val_loss: 1.4919 - val_accuracy: 0.3355
# Epoch 146/150
# 306/306 [==============================] - 1s 2ms/step - loss: 1.5103 - accuracy: 0.3241 - val_loss: 1.4920 - val_accuracy: 0.3355
# Epoch 147/150
# 306/306 [==============================] - 0s 1ms/step - loss: 1.4998 - accuracy: 0.3173 - val_loss: 1.4918 - val_accuracy: 0.3355
# Epoch 148/150
# 306/306 [==============================] - 0s 1ms/step - loss: 1.4963 - accuracy: 0.3318 - val_loss: 1.4920 - val_accuracy: 0.3355
# Epoch 149/150
# 306/306 [==============================] - 1s 2ms/step - loss: 1.4959 - accuracy: 0.3371 - val_loss: 1.4919 - val_accuracy: 0.3355
# Epoch 150/150
# 306/306 [==============================] - 0s 1ms/step - loss: 1.5042 - accuracy: 0.3197 - val_loss: 1.4918 - val_accuracy: 0.3355
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])
# 16/16 [==============================] - 0s 736us/step - loss: 1.4973 - accuracy: 0.3280
# {'loss': [1.4973454475402832], 'accuracy': [0.328000009059906], 'true_classes': [array([2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2,
#        2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2,
#        2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2,
#        2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2,
#        2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2], dtype=int64)], 'pred_classes': [array([2, 0, 2, 3, 4, 0, 3, 1, 1, 1, 2, 1, 4, 3, 2, 2, 3, 3, 2, 0, 0, 1,
#        1, 2, 3, 3, 2, 0, 0, 2, 4, 4, 1, 2, 0, 2, 4, 1, 3, 3, 3, 3, 3, 2,
#        1, 1, 3, 1, 0, 1, 1, 1, 1, 3, 0, 2, 3, 0, 2, 1, 3, 2, 1, 2, 3, 2,
#        3, 3, 1, 0, 2, 2, 1, 3, 4, 1, 3, 2, 3, 2, 1, 2, 2, 1, 1, 0, 2, 3,
#        0, 3, 1, 2, 0, 0, 2, 3, 2, 1, 3, 3], dtype=int64)], 'load': [189     5
# 363     0
# 123    10
# 108    13
# 32     15
#        ..
# 128    11
# 383    10
# 22      2
# 101     7
# 343    14
# Name: Load Alias, Length: 100, dtype: int64], 'power': [189    244
# 363    263
# 123    243
# 108    240
# 32     245
#       ...
# 128    240
# 383    243
# 22     245
# 101    278
# 343    250
# Name: Power (W), Length: 100, dtype: int64]}

# %% [markdown]
# ### Model Accuracy Plot

# %%
plt.style.use('fivethirtyeight')
plt.rcParams['figure.figsize'] = (7.0, 5.0)

plt.scatter(np.arange(1,len(cashe.get('class_4')['accuracy'])+1),
           cashe.get('class_4')['accuracy'],label='Accuracy' )

plt.plot(5.5,np.sum((cashe.get('class_4')['accuracy']))/len(cashe.get('class_4')['accuracy']),
         marker='o', linestyle='none', markersize=10,color='k',label='Average Accuracy')
#plt.yticks(np.arange(0.978,0.987,0.001))
plt.xticks(np.arange(1, 11,1))
plt.title(f'Accuracy of Model on Test Data',color='#4390cb')
plt.xlabel('Number of Iterations',color='#4390cb')
plt.ylabel('Model Accuracy per Interation',color='#4390cb')
plt.legend(loc=1,bbox_to_anchor=(1.40,1))
plt.savefig(f'Model_1_Accuracy.png',bbox_inches='tight')

plt.show()

# %%
plt.scatter(np.arange(1,len(cashe.get('class_4')['loss'])+1),
           cashe.get('class_4')['loss'],label='Loss per Iteration' )

plt.plot(5.5,np.sum((cashe.get('class_4')['loss']))/len(cashe.get('class_4')['loss']),
         marker='o', linestyle='none', markersize=10,color='k',label='Average Loss')
#plt.yticks(np.arange(0.059,0.133,0.01))
plt.xticks(np.arange(1, 11,1))
plt.title(f'Loss of Model on Test Data',color='#4390cb')
plt.xlabel('Number of Iterations',color='#4390cb')
plt.ylabel('Model Loss per Interation',color='#4390cb')
plt.legend(loc=1, bbox_to_anchor=(1,1))
plt.savefig(f'Model_1_Loss.png',bbox_inches='tight')
plt.show()

# %%
# Out:
# <class 'pandas.core.series.Series'>
# <class 'pandas.core.series.Series'>
# <class 'pandas.core.series.Series'>
# <class 'pandas.core.series.Series'>
# <class 'pandas.core.series.Series'>
# <class 'pandas.core.series.Series'>
# <class 'pandas.core.series.Series'>
# <class 'pandas.core.series.Series'>
# <class 'pandas.core.series.Series'>

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sn
y_test=[]
y_predicted =[]
for i in range(1,10):
    df= pd.read_csv(f"pred3_{i}.csv")
    y_test.extend(df["Class_3"].to_list())
    y_predicted.extend(df["Pred_BT_Class"].to_list())
print(f"Test: {len(y_test)}")
print(f"Pred: {len(y_predicted)}")
cm = confusion_matrix(y_test, y_predicted)
cm_df = pd.DataFrame(cm,
                     index = ['Class1','Class2','Class3'], 
                     columns = ['Class1','Class2','Class3'])
group_counts = ["{0:0.0f}".format(value) for value in
                cm.flatten()]
plt.figure(figsize = (10,7))
plt.tight_layout()

group_names=["(cell 1)","(cell 2)","(cell 3)",
        "(cell 4)","(cell 5)","(cell 6)",
        "(cell 7)","(cell 8)","(cell 9)"]
labels = [f"{v1}\n{v2}" for v1, v2 in
          zip(group_counts,group_names)]
labels = np.asarray(labels).reshape(3,3)
sns.set(style='white')
sns.set(font_scale=2.5) # Adjust to fit
sns.heatmap(cm_df, annot=labels, fmt='', cmap='Blues')
#plt.title('Confusion Matrix of FASTory Belt Tension Class Predictor ANN Model ',fontsize=15)
plt.ylabel('Actual Belt Tension Class',fontsize=15)
plt.xlabel('Predicted Belt Tension Class',fontsize=15)
plt.savefig('confusionMat.png', dpi=500)
plt.show()
# labels = ["True Neg","False Pos","False Neg","True Pos"]
# labels = np.asarray(labels).reshape(2,2)
#sns.heatmap(cm, annot=True, fmt='', cmap='Blues')
# cm = confusion_matrix(y_test, y_predicted,labels=[1,2,3]).reshape(-1)
# print('Outcome values : n', TP, FN, FP, TN)
#cm
#after creating the confusion matrix, for better understaning plot the cm.
# import seaborn as sn
# plt.figure(figsize = (10,7))
# sn.heatmap(cm, annot=True)
# plt.xlabel('Predicted')
# plt.ylabel('Truth')
# Out:
# Test: 900
# Pred: 900
